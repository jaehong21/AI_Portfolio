# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
xdomain = np.arange(15)
lossSet = [0.2201940417289734, 0.06096755340695381, 0.04610774666070938, 0.03664808347821236, 0.03001343458890915, 0.026329422369599342, 0.020648084580898285, 0.01864520274102688, 0.015505973249673843, 0.013331638649106026, 0.011736650951206684, 0.008551311679184437, 0.008189844898879528, 0.005969956982880831, 0.007618204690515995]
xdomain = xdomain + 1

plt.plot(xdomain, lossSet, marker='o', color='red')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Loss of CNN Model")
plt.show()
